# %%
from sklearn.datasets import make_regression
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score
import seaborn as sns
sns.set_style('whitegrid')
sns.set_palette('deep')
sns.set_theme('notebook', font_scale=1.5, rc={"lines.linewidth": 2.5})

# %%
X,y = make_regression(n_samples=100, n_features=1, n_informative=1, n_targets=1,  noise=20, random_state=13)

# %%
sns.scatterplot(x=X.flatten(), y=y)
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(
    X,
    y,
    random_state=2,
    test_size=0.2
)

# %%
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import mean_squared_error, r2_score
lr = LinearRegression()
lr.fit(X_train,y_train)

print(f"conefficient_score = {lr.coef_[0]}")
print(f"intercept_score    = {lr.intercept_}")
print (f"mean_squared_error = {mean_squared_error(y_test, lr.predict(X_test))}")
print (f"r2_score = {r2_score(y_test, lr.predict(X_test))}")
# Out:
# conefficient_score = 28.125973315135607
# intercept_score    = -2.271014426178382
# mean_squared_error = 212.1980691451566
# r2_score = 0.6345158782661013

# %%
class GDRegressor ():
    def __init__(self,learning_rate,epochs):
        self.m = 1
        self.b = 0
        self.lr=learning_rate
        self.epochs =epochs
    def fit (self,X,y):
        for i in range (self.epochs):
            loss_slope_b = -2*np.sum( y - self.m*X.ravel() - self.b )

            loss_slope_m = -2 * np.sum((y - self.m*X.ravel() - self.b)*X.ravel())

            self.m = self.m - (self.lr * loss_slope_m)
            self.b = self.b - (self.lr*loss_slope_b)



            print(f" m = {self.m}, b = {self.b}")
    def predict(self,X):
        return self.m * X +self.b
gd = GDRegressor(0.001,50)
gd.fit(X_train,y_train)
# Out:
#  m = 5.09827744420144, b = -0.1435474581801533
#  m = 8.575757062429808, b = -0.29733764259372086
#  m = 11.526735115379886, b = -0.4547010927256049
#  m = 14.031143268376976, b = -0.6107995898413177
#  m = 16.156743424502228, b = -0.7622167550549127
#  m = 17.960986148793598, b = -0.9066319374978642
#  m = 19.492584412412196, b = -1.0425613400889129
#  m = 20.792846405124628, b = -1.169153317989044
#  m = 21.896804419261745, b = -1.2860272297262965
#  m = 22.834171106597083, b = -1.3931472200319996
#  m = 23.63014958937192, b = -1.490723946434096
#  m = 24.30611983123439, b = -1.5791385943160414
#  m = 24.880220227697713, b = -1.6588846115611755
#  m = 25.367840461359297, b = -1.7305234785620922
#  m = 25.782039202216122, b = -1.7946515488721528
#  m = 26.133898148414055, b = -1.8518755801799525
#  m = 26.432822138929364, b = -1.9027950492908872
#  m = 26.686793577365258, b = -1.9479897286695333
#  m = 26.902588143317793, b = -1.988011312454028
#  m = 27.085957699185613, b = -2.0233781303214267
#  m = 27.241785395917166, b = -2.0545721893167364
#  m = 27.37421721569314, b = -2.08203794588601
#  m = 27.486773541532788, b = -2.1061823403379716
#  m = 27.582443795199755, b = -2.1273757298941334
#  m = 27.663766720270754, b = -2.145953439347507
#  m = 27.73289849388463, b = -2.162217714188363
#  m = 27.79167051757187, b = -2.176439913172239
#  m = 27.841638455423976, b = -2.1888628183840333
#  m = 27.884123848872317, b = -2.1997029730718007
#  m = 27.920249434887, b = -2.2091529826517675
#  m = 27.950969122876227, b = -2.2173837337529503
#  m = 27.977093440226014, b = -2.2245465011319174
#  m = 27.999311133257976, b = -2.2307749236786734
#  m = 28.018207506004128, b = -2.2361868393045854
#  m = 28.034279990729257, b = -2.240885974856181
#  m = 28.047951369140367, b = -2.244963491818196
#  m = 28.05958099965011, b = -2.2484993918419707
#  m = 28.06947435216261, b = -2.2515637883692383
#  m = 28.07789110614976, b = -2.2542180520610775
#  m = 28.08505202903256, b = -2.25651583858085
#  m = 28.09114481901712, b = -2.258504007670711
#  m = 28.096329068660324, b = -2.2602234425232
#  m = 28.100740481796695, b = -2.2617097782755415
#  m = 28.10449445640113, b = -2.2629940481166515
#  m = 28.107689128946426, b = -2.26410325505069
#  m = 28.110407961377582, b = -2.265060876848341
#  m = 28.112721939574655, b = -2.2658873111693896
#  m = 28.11469144178047, b = -2.2666002672808916
#  m = 28.11636782664705, b = -2.2672151102412084
#  m = 28.117794783066724, b = -2.267745162883301

# %%
import numpy as np

# 2D array
X = np.array([[1, 2, 3],
              [4, 5, 6]])

print("Original array:")
print(X)
print("Shape:", X.shape)

# Flatten using ravel
X_flat = X.ravel()

print("\nFlattened array:")
print(X_flat)
print("Shape:", X_flat.shape)
# Out:
# Original array:
# [[1 2 3]
#  [4 5 6]]
# Shape: (2, 3)
#
# Flattened array:
# [1 2 3 4 5 6]
# Shape: (6,)
