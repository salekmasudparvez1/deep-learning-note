# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import torch
from torchvision import datasets
import torch.nn as nn 
from torch.utils.data import DataLoader,TensorDataset
import torch.optim as optim

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("anokas/kuzushiji", output_dir="./datasets",force_download=True)

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 571M/571M [03:44<00:00, 2.67MB/s]
# Extracting files...
# Path to dataset files: ./datasets

# %%
df = pd.read_csv("./datasets/k49_classmap.csv")
df
char = chr(int("304A", 16))
print(char)
# Out:
# お

# %%
train_dataset = datasets.KMNIST(
    root="./data",
    train=True,
    download=False
)
test_dataset = datasets.KMNIST(
    root="./data",
    train=False,
    download=False
)
print(torchvision.datasets.KMNIST)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 train_dataset = datasets.KMNIST(
#       2     root="./data",
#       3     train=True,
#       4     download=False
#
# File ~/miniconda3/lib/python3.14/site-packages/torchvision/datasets/mnist.py:103, in MNIST.__init__(self, root, train, transform, target_transform, download)
#     100     self.download()
#     102 if not self._check_exists():
# --> 103     raise RuntimeError("Dataset not found. You can use download=True to download it")
#     105 self.data, self.targets = self._load_data()
#
# RuntimeError: Dataset not found. You can use download=True to download it

# %%
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [kagglehub]/3 [kagglesdk]
# ...
